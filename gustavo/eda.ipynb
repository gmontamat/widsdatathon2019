# %% [markdown]
# # Exploratory Data Analysis
#
# ## Import modules and load data

# %%
import matplotlib.pyplot as plt
import os
import pickle

from matplotlib.pyplot import imshow

# %matplotlib inline

# %%
data_path = os.path.join(os.getcwd(), '..', 'data')

# %%
with open(os.path.join(data_path, 'train_images_64x64.pkl'), 'rb') as fin:
    images = pickle.load(fin)
with open(os.path.join(data_path, 'train_responses.pkl'), 'rb') as fin:
    responses = pickle.load(fin)
with open(os.path.join(data_path, 'train_scores.pkl'), 'rb') as fin:
    scores = pickle.load(fin)

# %%
imshow(images[0,:,:,:])

# %%
images[0, :5, :5, 0]
# Out:
# array([[28, 28, 32, 27,  2],
#        [30, 30, 33, 18, 12],
#        [25, 24, 22,  1, 19],
#        [22, 19, 10,  9,  4],
#        [17, 14, 14, 12, 15]], dtype=uint8)

# %%
plt.hist(responses, bins=3)
plt.title("Class imbalance")
plt.show()

# %%
plt.hist(scores, bins='auto')
plt.title("Distribution of scores")
plt.show()
